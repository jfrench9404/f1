# %%
import pandas as pd
import time

import pandas as pd
import requests

# Endpoint to get all sessions
SESSIONS_URL = "https://api.openf1.org/v1/sessions"

# Step 1: Get session data
response = requests.get(SESSIONS_URL)
response.raise_for_status()  # Raise error if API call fails

sessions = pd.DataFrame(response.json())

# Step 2: Filter to just race sessions (session_type == 'RACE')
race_sessions = sessions[sessions['session_type'].str.upper() == 'RACE']

# Step 3: Keep only meeting_key and circuit_short_name
race_info = race_sessions[['meeting_key', 'circuit_short_name']].drop_duplicates().sort_values('meeting_key')

# Optional: reset index
race_info.reset_index(drop=True, inplace=True)

# %%
driver_country_codes = {
    "Max VERSTAPPEN": "NLD",
    "Sergio PEREZ": "MEX",
    "Charles LECLERC": "MCO",
    "Carlos SAINZ": "ESP",
    "George RUSSELL": "GBR",
    "Lewis HAMILTON": "GBR",
    "Lando NORRIS": "GBR",
    "Oscar PIASTRI": "AUS",
    "Fernando ALONSO": "ESP",
    "Lance STROLL": "CAN",
    "Kevin MAGNUSSEN": "DNK",
    "Nico HULKENBURG": "DEU",
    "Gabriel BORTOLETO": "BRA",
    "Liam LAWSON": "NZL",
    "Zhou GUANYU": "CHN",
    "Valtteri BOTTAS": "FIN",
    "Oliver BEARMAN": "GBR",
    "Franco COLAPINTO": "ARG",
    "Esteban OCON": "FRA",
    "Pierre GASLY": "FRA",
    "Yuki TSUNODA": "JPN",
    "Daniel RICCARDO": "AUS",
    "Logan SARGENT": "USA",
    "Alex ALBON": "THA",
    "Isack HADJAR": "FRA",
    "Kimi ANTONELLI": "ITA"
}

# %%
# ---------- LAP PROCESSING ----------
def process_lap_data(laps_df: pd.DataFrame):
    if laps_df.empty:
        return pd.DataFrame()
    valid_laps = laps_df[
        (laps_df['is_pit_out_lap'] == False) &
        (laps_df['lap_duration'].notna()) &
        (laps_df['lap_duration'] > 0)
    ]
    summary = valid_laps.groupby(['driver_number', 'session_key', 'meeting_key']).agg(
        best_lap_time=('lap_duration', 'min'),
        avg_lap_time=('lap_duration', 'mean'),
        lap_consistency=('lap_duration', 'std'),
        best_sector_1=('duration_sector_1', 'min'),
        best_sector_2=('duration_sector_2', 'min'),
        best_sector_3=('duration_sector_3', 'min'),
        best_i1_speed=('i1_speed', 'max'),
        best_i2_speed=('i2_speed', 'max'),
        best_st_speed=('st_speed', 'max'),
        total_valid_laps=('lap_duration', 'count')
    ).reset_index()
    return summary

# ---------- DRIVER MERGE ----------
def merge_with_driver_info(lap_summary_df: pd.DataFrame, drivers_df: pd.DataFrame):
    if lap_summary_df.empty or drivers_df.empty:
        return pd.DataFrame()

    # 🔧 Force consistent dtypes and clean columns
    drivers_df = drivers_df.copy()
    drivers_df.columns = drivers_df.columns.str.strip()
    drivers_df['driver_number'] = drivers_df['driver_number'].astype(str)
    drivers_df['country_code'] = drivers_df['full_name'].map(driver_country_codes)

    lap_summary_df['driver_number'] = lap_summary_df['driver_number'].astype(str)

    drivers_trimmed = drivers_df.drop_duplicates(subset='driver_number')[
        ['driver_number', 'broadcast_name', 'full_name', 'team_name', 'country_code']
    ]
    enriched_df = pd.merge(lap_summary_df, drivers_trimmed, on='driver_number', how='left')
    return enriched_df


# ---------- API FETCH ----------
def fetch_openf1(
    endpoint,
    meeting_key=None,
    session_type=None,
    session_key=None,
    enrich_laps=False,
    drivers_df=None,
    retries=3,
    wait=2
):
    base = "https://api.openf1.org/v1/"
    url = f"{base}{endpoint}?"

    if session_key:
        url += f"session_key={session_key}"
    elif meeting_key:
        url += f"meeting_key={meeting_key}"
        if session_type:
            url += f"&session_type={session_type}"

    for attempt in range(retries):
        try:
            df = pd.read_json(url)
            if df.empty:
                print(f"⚠️ No data for {endpoint} | session_key={session_key} | meeting_key={meeting_key}")
                return df

            # ✅ Always keep context keys
            df['meeting_key'] = meeting_key
            if session_key:
                df['session_key'] = session_key

            # ✅ Optional enrichment for lap data
            if enrich_laps and endpoint == 'laps':
                df = process_lap_data(df)
                if drivers_df is not None and not drivers_df.empty:
                    df = merge_with_driver_info(df, drivers_df)

            # ✅ Attach source label
            df['source'] = endpoint

            # ✅ Attach circuit name upstream if possible
            if 'meeting_key' in df.columns and 'circuit_short_name' not in df.columns:
                df['circuit'] = df['meeting_key'].map(
                    race_info.set_index('meeting_key')['circuit_short_name']
                )

            # ✅ Print using session_type if available
            session_info = session_key_map.get(session_key, session_type or "—")
            print(f"✅ {endpoint.upper()} | Rows: {len(df)} | session: {session_info} | meeting_key={meeting_key}")

            time.sleep(wait)
            return df

        except Exception as e:
            print(f"❌ Attempt {attempt+1} failed for {endpoint} — {e}")
            time.sleep(wait * (attempt + 1))

    return pd.DataFrame()


# ----------- WRAPPER FOR SOURCE TAGGING ----------
def tagged_fetch(endpoint, **kwargs):
    df = fetch_openf1(endpoint, **kwargs)
    return df

# ---------- SESSION METADATA ----------
print("🔄 Getting session metadata...")
sessions = pd.read_json("https://api.openf1.org/v1/sessions")

# Create mappings from session_key → session_name
session_name_map = sessions.set_index('session_key')['session_name'].to_dict()

# Filter to real races
races = sessions[
    (sessions['session_type'].str.lower() == 'race') &
    (sessions['session_name'].str.upper() == 'RACE')
]
unique_races = races.drop_duplicates(subset='meeting_key')
recent_races = unique_races.sort_values('date_start', ascending=False)
last_3_meeting_keys = recent_races['meeting_key'].head(3).tolist()
print("✅ Last 3 meeting_keys:", last_3_meeting_keys)

# Create session_type mapping from session_key
session_key_map = sessions.set_index("session_key")["session_type"].to_dict()

# ---------- LOOP PER RACE ----------
all_data = []

for mk in last_3_meeting_keys:
    print(f"\n📦 Processing meeting_key={mk}...")

    # Fetch session_keys for this meeting
    session_keys_df = sessions[sessions['meeting_key'] == mk]
    session_keys_df = session_keys_df[['session_key', 'session_name']].sort_values('session_key')
    session_keys = session_keys_df.to_dict('records')

    # Pull drivers once per meeting
    drivers_df = tagged_fetch("drivers", meeting_key=mk)

    # Pull other data for the whole weekend
    all_data.extend([
        tagged_fetch("pit", meeting_key=mk),
        tagged_fetch("stints", meeting_key=mk),
        tagged_fetch("position", meeting_key=mk),
        drivers_df,
        tagged_fetch("weather", meeting_key=mk),
        tagged_fetch("race_control", meeting_key=mk)
    ])

    # Now pull lap data per session_key
    for sess in session_keys:
        skey = sess['session_key']
        sname = sess['session_name'].upper()
        if any(x in sname for x in ["PRACTICE", "QUALIFYING", "RACE"]):
            laps_df = tagged_fetch("laps", session_key=skey, meeting_key=mk, enrich_laps=True, drivers_df=drivers_df)
            all_data.append(laps_df)

# ---------- DONE ----------
print(f"\n✅ Data collection complete. all_data contains {len(all_data)} tagged DataFrames.")
# Out:
# 🔄 Getting session metadata...
# ✅ Last 3 meeting_keys: [1266, 1265, 1277]
#
# 📦 Processing meeting_key=1266...
# ✅ DRIVERS | Rows: 100 | session: — | meeting_key=1266
# ✅ PIT | Rows: 479 | session: — | meeting_key=1266
# ✅ STINTS | Rows: 456 | session: — | meeting_key=1266
# ✅ POSITION | Rows: 3942 | session: — | meeting_key=1266
# ✅ WEATHER | Rows: 481 | session: — | meeting_key=1266
# ✅ RACE_CONTROL | Rows: 173 | session: — | meeting_key=1266
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1266
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1266
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1266
# ✅ LAPS | Rows: 20 | session: Qualifying | meeting_key=1266
# ✅ LAPS | Rows: 20 | session: Race | meeting_key=1266
#
# 📦 Processing meeting_key=1265...
# ✅ DRIVERS | Rows: 100 | session: — | meeting_key=1265
# ✅ PIT | Rows: 253 | session: — | meeting_key=1265
# ✅ STINTS | Rows: 308 | session: — | meeting_key=1265
# ✅ POSITION | Rows: 3314 | session: — | meeting_key=1265
# ✅ WEATHER | Rows: 539 | session: — | meeting_key=1265
# ✅ RACE_CONTROL | Rows: 351 | session: — | meeting_key=1265
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1265
# ✅ LAPS | Rows: 20 | session: Qualifying | meeting_key=1265
# ✅ LAPS | Rows: 20 | session: Qualifying | meeting_key=1265
# ✅ LAPS | Rows: 20 | session: Race | meeting_key=1265
#
# 📦 Processing meeting_key=1277...
# ✅ DRIVERS | Rows: 100 | session: — | meeting_key=1277
# ✅ PIT | Rows: 406 | session: — | meeting_key=1277
# ✅ STINTS | Rows: 426 | session: — | meeting_key=1277
# ✅ POSITION | Rows: 3337 | session: — | meeting_key=1277
# ✅ WEATHER | Rows: 486 | session: — | meeting_key=1277
# ✅ RACE_CONTROL | Rows: 308 | session: — | meeting_key=1277
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1277
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1277
# ✅ LAPS | Rows: 20 | session: Practice | meeting_key=1277
# ✅ LAPS | Rows: 20 | session: Qualifying | meeting_key=1277
# ✅ LAPS | Rows: 18 | session: Race | meeting_key=1277
#
# ✅ Data collection complete. all_data contains 32 tagged DataFrames.

# %%
lap_dfs     = [df for df in all_data if not df.empty and df['source'].iloc[0] == 'laps']
pit_dfs     = [df for df in all_data if not df.empty and df['source'].iloc[0] == 'pit']
stint_dfs   = [df for df in all_data if not df.empty and df['source'].iloc[0] == 'stints']
driver_dfs  = [df for df in all_data if not df.empty and df['source'].iloc[0] == 'drivers']
position_dfs= [df for df in all_data if not df.empty and df['source'].iloc[0] == 'position']
weather_dfs = [df for df in all_data if not df.empty and df['source'].iloc[0] == 'weather']
rc_dfs      = [df for df in all_data if not df.empty and df['source'].iloc[0] == 'race_control']

# %%
def build_driver_card(driver_number, driver_df, lap_dfs, pit_dfs, stint_dfs, position_df, weather_df, rc_df, circuit_map):
    # 📋 Metadata
    driver_meta = driver_df[driver_df['driver_number'] == driver_number].iloc[0]
    full_name = driver_meta['full_name']
    broadcast = driver_meta['broadcast_name']
    team = driver_meta['team_name']
    country = driver_country_codes.get(full_name, 'Unknown')
    
    print(f"\n🏎️  Driver: {full_name} ({broadcast})")
    print(f"🏁 Team: {team} | Country: {country}")

    # 📊 Lap Summary
    print("\n📊 Lap Performance:")
    
    all_laps = pd.concat(lap_dfs)
    all_laps['driver_number'] = all_laps['driver_number'].astype(str)
    driver_number = str(driver_number)

    driver_laps = all_laps[all_laps['driver_number'] == driver_number]
    print(f"🔍 Lap entries found for driver {driver_number}: {len(driver_laps)}")

    if not driver_laps.empty:
        for _, row in driver_laps.iterrows():
            circuit_name = row.get('circuit', 'Unknown')
            session_label = session_name_map.get(row['session_key'], row['session_key'])

            print(f"  {circuit_name} - {session_label}: "
                f"Best Lap = {row.get('best_lap_time', '?'):.3f}s | "
                f"Avg = {row.get('avg_lap_time', '?'):.3f}s | "
                f"Consistency = {row.get('lap_consistency', '?'):.3f}s")
    else:
        print("  No lap data available.")

    # ⛽ Pit Summary
    print("\n⛽ Pit Stops:")
    all_pits = pd.concat(pit_dfs)
    driver_number = int(driver_number)
    driver_pits = all_pits[all_pits['driver_number'] == driver_number]

    if not driver_pits.empty:
        for _, row in driver_pits.iterrows():
            # ✅ Insert circuit name
            circuit_row = circuit_map[circuit_map['meeting_key'] == row['meeting_key']]
            circuit_name = circuit_row['circuit_short_name'].values[0] if not circuit_row.empty else "Unknown"
            session_label = session_name_map.get(row['session_key'], row['session_key'])

            lap = int(row['lap_number']) if pd.notna(row['lap_number']) else "?"
            duration = round(row['pit_duration'], 3) if pd.notna(row['pit_duration']) else "?"
            print(f"  {circuit_name} - {session_label}: 🔁 Lap {lap} | Duration: {duration}s")
    else:
        print("  No pit stop data available.")

    # 🛞 Stint Summary
    print("\n🛞 Tire Stints:")
    all_stints = pd.concat(stint_dfs)
    driver_stints = all_stints[all_stints['driver_number'] == driver_number]
    if not driver_stints.empty:
        for _, row in driver_stints.iterrows():
            # ✅ Insert circuit name
            circuit_row = circuit_map[circuit_map['meeting_key'] == row['meeting_key']]
            circuit_name = circuit_row['circuit_short_name'].values[0] if not circuit_row.empty else "Unknown"
            session_label = session_name_map.get(row['session_key'], row['session_key'])

            print(f"  {circuit_name} - {session_label}: Stint {row['stint_number']}: Laps {row['lap_start']}–{row.get('lap_end', '?')} | Compound: {row['compound']}")
    else:
        print("  No stint data available.")

    # 📈 Position Changes
    print("\n📈 Session Positions:")
    positions = position_df[position_df['driver_number'] == driver_number]

    if not positions.empty:
        grouped = (
            positions
            .groupby(['meeting_key', 'session_key', 'circuit'])['position']
            .agg(['first', 'last'])
            .reset_index()
        )

        for _, row in grouped.iterrows():
            circuit_name = row['circuit']
            session_label = session_name_map.get(row['session_key'], row['session_key'])
            print(f"  {circuit_name} - {session_label}: Grid → {int(row['first'])}, Finish → {int(row['last'])}")
    else:
        print("  No position data available.")


    # 🌦️ Weather Context
    print("\n🌦️ Weather Summary:")

    weather_summary = (
        weather_df
        .groupby(['meeting_key', 'session_key', 'circuit'])['rainfall']
        .max()
        .reset_index()
    )

    for _, row in weather_summary.iterrows():
        rain = float(row['rainfall'])
        condition = "Wet" if rain > 0 else "Dry"
        session_label = session_name_map.get(row['session_key'], row['session_key'])
        print(f"  {row['circuit']} - {session_label}: {condition} (Max Rainfall: {rain:.2f})")

    # 🚩 Incidents
    print("\n🚩 Race Control Events:")
    driver_incidents = rc_df[rc_df['driver_number'] == driver_number] if 'driver_number' in rc_df.columns else pd.DataFrame()
    if not driver_incidents.empty:
        for _, row in driver_incidents.iterrows():
            session_label = session_name_map.get(row['session_key'], row['session_key'])
            circuit_row = circuit_map[circuit_map['meeting_key'] == row['meeting_key']]
            circuit_name = circuit_row['circuit_short_name'].values[0] if not circuit_row.empty else "Unknown"

            print(f" {circuit_name} - {session_label} [{row['flag']} @ {row['date']}] Reason: {row.get('message', 'N/A')}")
    else:
        print("  No incidents recorded.")

    print("\n" + "-"*60)

# %%
# Combine all drivers into one DataFrame
driver_df = pd.concat(driver_dfs, ignore_index=True)
position_df = pd.concat(position_dfs, ignore_index=True)
weather_df = pd.concat(weather_dfs, ignore_index=True)
rc_df = pd.concat(rc_dfs, ignore_index=True)

unclean_dfs = [driver_df, position_df, weather_df, rc_df]

for df in unclean_dfs:
    if 'meeting_key' in df.columns and 'circuit' not in df.columns:
        df['circuit'] = df['meeting_key'].map(race_info)
    if df is driver_df:
        df['country_code'] = df['full_name'].map(driver_country_codes).fillna('Unknown')

# Now loop over drivers
for driver_number in driver_df['driver_number'].unique():
    build_driver_card(
        driver_number,
        driver_df,
        lap_dfs,
        pit_dfs,
        stint_dfs,
        position_df,
        weather_df,
        rc_df,
        race_info
    )
# Out:
# 🏎️  Driver: Max VERSTAPPEN (M VERSTAPPEN)
# 🏁 Team: Red Bull Racing | Country: NLD
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 1: 14
#   Hungaroring - Practice 1: Best Lap = 76.940s | Avg = 95.612s | Consistency = 23.482s
#   Hungaroring - Practice 2: Best Lap = 76.791s | Avg = 90.577s | Consistency = 18.096s
#   Hungaroring - Practice 3: Best Lap = 76.162s | Avg = 95.833s | Consistency = 25.130s
#   Hungaroring - Qualifying: Best Lap = 75.547s | Avg = 87.445s | Consistency = 16.111s
#   Hungaroring - Race: Best Lap = 79.576s | Avg = 82.151s | Consistency = 1.281s
| Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 5: Laps 13–15 | Compound: SOFT
#   Spa-Francorchamps - Race: Stint 1: Laps 1–1 | Compound: INTERMEDIATE
#   Spa-Francorchamps - Race: Stint 2: Laps 2–12 | Compound: MEDIUM
#   Spa-Francorchamps - Race: Stint 3: Laps 13–44 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 1: Laps 1–7 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 2: Laps 8–10 | Compound: SOFT
#   Silverstone - Practice 1: Stint 3: Laps 11–13 | Compound: SOFT
#   Silverstone - Practice 1: Stint 4: Laps 14–26 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 1: Laps 1–3 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 2: Laps 4–6 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Practice 2: Stint 4: Laps 10–12 | Compound: SOFT
#   Silverstone - Practice 2: Stint 5: Laps 13–23 | Compound: MEDIUM
#   Silverstone - Practice 3: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Practice 3: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Practice 3: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Practice 3: Stint 4: Laps 10–12 | Compound: SOFT
#   Silverstone - Practice 3: Stint 5: Laps 13–14 | Compound: SOFT
#   Silverstone - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Silverstone - Qualifying: Stint 5: Laps 13–15 | Compound: SOFT
#   Silverstone - Qualifying: Stint 6: Laps 16–18 | Compound: SOFT
#   Silverstone - Race: Stint 1: Laps 1–11 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 2: Laps 12–41 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 3: Laps 42–52 | Compound: MEDIUM
#
# 📈 Session Positions:
#   Spa-Francorchamps - Practice 1: Grid → 1, Finish → 2
#   Spa-Francorchamps - Sprint Qualifying: Grid → 2, Finish → 2
#   Spa-Francorchamps - Sprint: Grid → 2, Finish → 1
#   Spa-Francorchamps - Qualifying: Grid → 2, Finish → 4
#   Spa-Francorchamps - Race: Grid → 4, Finish → 4
#   Hungaroring - Practice 1: Grid → 1, Finish → 5
#   Hungaroring - Practice 2: Grid → 1, Finish → 14
#   Hungaroring - Practice 3: Grid → 2, Finish → 12
#   Hungaroring - Qualifying: Grid → 12, Finish → 8
#   Hungaroring - Race: Grid → 9, Finish → 9
#   Silverstone - Practice 1: Grid → 1, Finish → 10
#   Silverstone - Practice 2: Grid → 1, Finish → 5
#   Silverstone - Practice 3: Grid → 1, Finish → 3
#   Silverstone - Qualifying: Grid → 3, Finish → 1
#   Silverstone - Race: Grid → 1, Finish → 5
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#   No incidents recorded.
#
# ------------------------------------------------------------
#
# 🏎️  Driver: Lando NORRIS (L NORRIS)
# 🏁 Team: McLaren | Country: GBR
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 4: 14
#   Hungaroring - Practice 1: Best Lap = 76.052s | Avg = 99.702s | Consistency = 23.003s
#   Hungaroring - Practice 2: Best Lap = 75.624s | Avg = 96.974s | Consistency = 21.806s
#   Hungaroring - Practice 3: Best Lap = 74.948s | Avg = 101.117s | Consistency = 23.213s
#   Hungaroring - Qualifying: Best Lap = 74.890s | Avg = 89.099s | Consistency = 14.936s
#   Hungaroring - Race: Best Lap = 79.918s | Avg = 81.340s | Consistency = 1.103s
#   Spa-Francorchamps - Practice 1: Best Lap = 102.526s | Avg = 126.236s | Consistency = 28.966s
#   Spa-Francorchamps - Sprint Qualifying: Best Lap = 101.128s | Avg = 122.997s | Consistency = 20.634s
#   Spa-Francorchamps - Qualifying: Best Lap = 100.562s | Avg = 120.179s | Consistency = 20.243s
#   Spa-Francorchamps - Race: Best Lap = 105.257s | Avg = 114.535s | Consistency = 18.388s
#   Silverstone - Practice 1: Best Lap = 86.915s | Avg = 110.619s | Consistency = 24.600s
#   Silverstone - Practice 2: Best Lap = 85.816s | Avg = 107.138s | Consistency = 23.212s
#   Silverstone - Practice 3: Best Lap = 85.606s | Avg = 101.642s | Consistency = 21.649s
#   Silverstone - Qualifying: Best Lap = 85.010s | Avg = 98.524s | Consistency = 14.325s
#   Silverstone - Race: Best Lap = 89.734s | Avg = 111.819s | Consistency = 22.921s
#
# ⛽ Pit Stops:
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 7 | Duration: 31.6s
#   Hungaroring - Practice 1: 🔁 Lap 13 | Duration: 612.9s
#   Hungaroring - Practice 1: 🔁 Lap 16 | Duration: 25.1s
#   Hungaroring - Practice 1: 🔁 Lap 18 | Duration: 398.9s
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 7 | Duration: 31.6s
#   Hungaroring - Practice 2: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 2: 🔁 Lap 8 | Duration: 432.8s
#   Hungaroring - Practice 2: 🔁 Lap 12 | Duration: 41.0s
#   Hungaroring - Practice 2: 🔁 Lap 15 | Duration: 344.1s
#   Hungaroring - Practice 2: 🔁 Lap 24 | Duration: 20.8s
#   Hungaroring - Practice 3: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 3: 🔁 Lap 2 | Duration: 907.2s
#   Hungaroring - Practice 3: 🔁 Lap 6 | Duration: 22.8s
#   Hungaroring - Practice 3: 🔁 Lap 9 | Duration: 29.9s
#   Hungaroring - Practice 3: 🔁 Lap 12 | Duration: 383.9s
#   Hungaroring - Practice 3: 🔁 Lap 15 | Duration: 142.7s
#   Hungaroring - Practice 3: 🔁 Lap 18 | Duration: 264.5s
#   Hungaroring - Qualifying: 🔁 Lap 1 | Duration: ?s
#   Hungaroring -
| Compound: SOFT
#   Hungaroring - Qualifying: Stint 6: Laps 16–18 | Compound: SOFT
#   Hungaroring - Race: Stint 1: Laps 1–31 | Compound: MEDIUM
#   Hungaroring - Race: Stint 2: Laps 32–70 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 1: Laps 1–7 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 2: Laps 8–16 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 3: Laps 17–22 | Compound: SOFT
#   Spa-Francorchamps - Sprint Qualifying: Stint 1: Laps 1–3 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 2: Laps 4–9 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 3: Laps 10–12 | Compound: SOFT
#   Spa-Francorchamps - Sprint: Stint 1: Laps 1–15 | Compound: MEDIUM
#   Spa-Francorchamps - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 2: Laps 4–8 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 3: Laps 9–11 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 4: Laps 12–14 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 5: Laps 15–17 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 6: Laps 18–20 | Compound: SOFT
#   Spa-Francorchamps - Race: Stint 1: Laps 1–1 | Compound: INTERMEDIATE
#   Spa-Francorchamps - Race: Stint 2: Laps 2–13 | Compound: HARD
#   Spa-Francorchamps - Race: Stint 3: Laps 14–44 | Compound: HARD
#   Silverstone - Practice 1: Stint 1: Laps 1–9 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 2: Laps 10–16 | Compound: SOFT
#   Silverstone - Practice 1: Stint 3: Laps 17–26 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 1: Laps 1–6 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 2: Laps 7–9 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 3: Laps 10–15 | Compound: SOFT
#   Silverstone - Practice 2: Stint 4: Laps 16–23 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 5: Laps 24–26 | Compound: SOFT
#   Silverstone - Practice 3: Stint 1: Laps 1–10 | Compound: SOFT
#   Silverstone - Practice 3: Stint 2: Laps 11–13 | Compound: SOFT
#   Silverstone - Practice 3: Stint 3: Laps 14–15 | Compound: SOFT
#   Silverstone - Practice 3: Stint 4: Laps 16–17 | Compound: SOFT
#   Silverstone - Qualifying: Stint 1: Laps 1–5 | Compound: SOFT
#   Silverstone - Qualifying: Stint 2: Laps 6–8 | Compound: SOFT
#   Silverstone - Qualifying: Stint 3: Laps 9–11 | Compound: SOFT
#   Silverstone - Qualifying: Stint 4: Laps 12–14 | Compound: SOFT
#   Silverstone - Qualifying: Stint 5: Laps 15–17 | Compound: SOFT
#   Silverstone - Qualifying: Stint 6: Laps 18–20 | Compound: SOFT
#   Silverstone - Race: Stint 1: Laps 1–11 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 2: Laps 12–44 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 3: Laps 45–52 | Compound: MEDIUM
#
# 📈 Session Positions:
#   Spa-Francorchamps - Practice 1: Grid → 2, Finish → 3
#   Spa-Francorchamps - Sprint Qualifying: Grid → 3, Finish → 3
#   Spa-Francorchamps - Sprint: Grid → 3, Finish → 3
#   Spa-Francorchamps - Qualifying: Grid → 3, Finish → 1
#   Spa-Francorchamps - Race: Grid → 1, Finish → 2
#   Hungaroring - Practice 1: Grid → 2, Finish → 1
#   Hungaroring - Practice 2: Grid → 2, Finish → 1
#   Hungaroring - Practice 3: Grid → 1, Finish → 2
#   Hungaroring - Qualifying: Grid → 2, Finish → 3
#   Hungaroring - Race: Grid → 4, Finish → 1
#   Silverstone - Practice 1: Grid → 2, Finish → 2
#   Silverstone - Practice 2: Grid → 2, Finish → 1
#   Silverstone - Practice 3: Grid → 2, Finish → 4
#   Silverstone - Qualifying: Grid → 4, Finish → 3
#   Silverstone - Race: Grid → 3, Finish → 1
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#   No incidents recorded.
#
# ------------------------------------------------------------
#
# 🏎️  Driver: Gabriel BORTOLETO (G BORTOLETO)
# 🏁 Team: Kick Sauber | Country: BRA
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 5: 14
#   Hungaroring - Practice 1: Best Lap = 77.652s | Avg = 102.811s | Consistency = 19.146s
#   Hungaroring - Practice 2: Best Lap = 76.946s | Avg = 94.734s | Consistency = 18.344s
#   Hungaroring - Practice 3: Best Lap = 75.978s | Avg = 95.634s | Consistency = 22.047s
#   Hungaroring - Qualifying: Best Lap = 75.586s | Avg = 89.255s | Consistency = 15.135s
#   Hungaroring - Race: Best Lap = 80.705s | Avg = 82.301s | Consistency = 1.177s
#   Spa-Francorchamps - Practice 1: Best Lap = 103.262s | Avg = 127.402s | Consistency = 28.035s
#   Spa-Francorchamps - Sprint Qualifying: Best Lap = 101.901s | Avg = 125.606s | Consistency = 31.047s
#   Spa-Francorchamps - Qualifying: Best Lap = 101.336s | Avg = 120.389s | Consistency = 25.661s
#   Spa-Francorchamps - Race: Best Lap = 106.966s | Avg = 115.406s | Consistency = 17.386s
#   Silverstone - Practice 1: Best Lap = 88.397s | Avg = 108.069s | Consistency = 22.676s
#   Silverstone - Practice 2: Best Lap = 86.904s | Avg = 106.783s | Consistency = 24.073s
#   Silverstone - Practice 3: Best Lap = 86.501s | Avg = 102.421s | Consistency = 18.257s
#   Silverstone - Qualifying: Best Lap = 86.446s | Avg = 98.795s | Consistency = 16.354s
#   Silverstone - Race: Best Lap = 136.121s | Avg = 136.951s | Consistency = 1.173s
#
# ⛽ Pit Stops:
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 4 | Duration: 16.5s
#   Hungaroring - Practice 1: 🔁 Lap 12 | Duration: 758.8s
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 4 | Duration: 16.5s
#   Hungaroring - Practice 2: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice
| Compound: SOFT
#   Hungaroring - Qualifying: Stint 6: Laps 16–18 | Compound: SOFT
#   Hungaroring - Race: Stint 1: Laps 1–40 | Compound: MEDIUM
#   Hungaroring - Race: Stint 2: Laps 41–70 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 1: Laps 1–9 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 2: Laps 10–11 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 3: Laps 12–19 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 4: Laps 20–25 | Compound: SOFT
#   Spa-Francorchamps - Sprint Qualifying: Stint 1: Laps 1–3 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 2: Laps 4–6 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 3: Laps 7–9 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Spa-Francorchamps - Sprint: Stint 1: Laps 1–15 | Compound: MEDIUM
#   Spa-Francorchamps - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 5: Laps 13–15 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 6: Laps 16–18 | Compound: SOFT
#   Spa-Francorchamps - Race: Stint 1: Laps 1–1 | Compound: INTERMEDIATE
#   Spa-Francorchamps - Race: Stint 2: Laps 2–12 | Compound: MEDIUM
#   Spa-Francorchamps - Race: Stint 3: Laps 13–44 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 1: Laps 1–10 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 2: Laps 11–12 | Compound: SOFT
#   Silverstone - Practice 1: Stint 3: Laps 13–23 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 1: Laps 1–5 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 2: Laps 6–10 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 3: Laps 11–13 | Compound: SOFT
#   Silverstone - Practice 2: Stint 4: Laps 14–22 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 5: Laps 23–27 | Compound: SOFT
#   Silverstone - Practice 3: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Practice 3: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Practice 3: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Practice 3: Stint 4: Laps 10–12 | Compound: SOFT
#   Silverstone - Practice 3: Stint 5: Laps 13–13 | Compound: SOFT
#   Silverstone - Practice 3: Stint 6: Laps 14–15 | Compound: SOFT
#   Silverstone - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Race: Stint 1: Laps 1–3 | Compound: MEDIUM
#
# 📈 Session Positions:
#   Spa-Francorchamps - Practice 1: Grid → 3, Finish → 13
#   Spa-Francorchamps - Sprint Qualifying: Grid → 13, Finish → 10
#   Spa-Francorchamps - Sprint: Grid → 10, Finish → 9
#   Spa-Francorchamps - Qualifying: Grid → 13, Finish → 10
#   Spa-Francorchamps - Race: Grid → 10, Finish → 9
#   Hungaroring - Practice 1: Grid → 3, Finish → 17
#   Hungaroring - Practice 2: Grid → 3, Finish → 17
#   Hungaroring - Practice 3: Grid → 4, Finish → 9
#   Hungaroring - Qualifying: Grid → 9, Finish → 7
#   Hungaroring - Race: Grid → 6, Finish → 6
#   Silverstone - Practice 1: Grid → 3, Finish → 20
#   Silverstone - Practice 2: Grid → 3, Finish → 13
#   Silverstone - Practice 3: Grid → 3, Finish → 16
#   Silverstone - Qualifying: Grid → 16, Finish → 17
#   Silverstone - Race: Grid → 16, Finish → 18
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#   No incidents recorded.
#
# ------------------------------------------------------------
#
# 🏎️  Driver: Isack HADJAR (I HADJAR)
# 🏁 Team: Racing Bulls | Country: FRA
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 6: 14
#   Hungaroring - Practice 1: Best Lap = 76.681s | Avg = 102.850s | Consistency = 23.647s
#   Hungaroring - Practice 2: Best Lap = 76.427s | Avg = 93.728s | Consistency = 21.283s
#   Hungaroring - Practice 3: Best Lap = 76.956s | Avg = 105.961s | Consistency = 23.055s
#   Hungaroring - Qualifying: Best Lap = 75.469s | Avg = 89.666s | Consistency = 17.130s
#   Hungaroring - Race: Best Lap = 80.802s | Avg = 82.636s | Consistency = 1.336s
#   Spa-Francorchamps - Practice 1: Best Lap = 103.122s | Avg = 126.543s | Consistency = 25.441s
#   Spa-Francorchamps - Sprint Qualifying: Best Lap = 101.971s | Avg = 118.257s | Consistency = 20.680s
#   Spa-Francorchamps - Qualifying: Best Lap = 101.281s | Avg = 114.218s | Consistency = 15.368s
#   Spa-Francorchamps - Race: Best Lap = 107.667s | Avg = 116.998s | Consistency = 17.395s
#   Silverstone - Practice 1: Best Lap = 87.217s | Avg = 109.431s | Consistency = 21.476s
#   Silverstone - Practice 2: Best Lap = 86.524s | Avg = 102.167s | Consistency = 19.284s
#   Silverstone - Practice 3: Best Lap = 86.129s | Avg = 102.650s | Consistency = 17.869s
#   Silverstone - Qualifying: Best Lap = 85.864s | Avg = 95.033s | Consistency = 10.088s
#   Silverstone - Race: Best Lap = 101.705s | Avg = 126.683s | Consistency = 21.351s
#
# ⛽ Pit Stops:
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 10 | Duration: 182.1s
#   Hungaroring - Practice 1: 🔁 Lap 18 | Duration: 278.6s
#   Hungaroring - Practice 1: 🔁 Lap 24 | Duration: 283.3s
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 2: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 2: 🔁 Lap 4 | Duration: 31.2s
#   Hungaroring - Practice 2: 🔁 Lap 10 | Duration: 542.9s
#   Hungaroring - Practice 2: 🔁 Lap 13 | Duration: 375.5s
#   Hungaroring - Practice 2: 🔁 Lap 27 | Duration: 21.4s
#   Hungaroring - Practice 3: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice
| Compound: SOFT
#   Hungaroring - Practice 3: Stint 4: Laps 14–14 | Compound: MEDIUM
#   Hungaroring - Practice 3: Stint 5: Laps 15–15 | Compound: MEDIUM
#   Hungaroring - Practice 3: Stint 6: Laps 16–18 | Compound: MEDIUM
#   Hungaroring - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 5: Laps 13–15 | Compound: SOFT
#   Hungaroring - Race: Stint 1: Laps 1–33 | Compound: MEDIUM
#   Hungaroring - Race: Stint 2: Laps 34–69 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 1: Laps 1–9 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 2: Laps 10–13 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 3: Laps 14–19 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 1: Laps 1–3 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 2: Laps 4–5 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 3: Laps 6–8 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 4: Laps 9–11 | Compound: SOFT
#   Spa-Francorchamps - Sprint: Stint 1: Laps 1–15 | Compound: MEDIUM
#   Spa-Francorchamps - Qualifying: Stint 1: Laps 1–1 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 2: Laps 2–4 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 3: Laps 5–7 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 4: Laps 8–10 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 5: Laps 11–13 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 6: Laps 14–16 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 7: Laps 17–19 | Compound: SOFT
#   Spa-Francorchamps - Race: Stint 1: Laps 1–1 | Compound: INTERMEDIATE
#   Spa-Francorchamps - Race: Stint 2: Laps 2–13 | Compound: MEDIUM
#   Spa-Francorchamps - Race: Stint 3: Laps 14–43 | Compound: HARD
#   Silverstone - Practice 1: Stint 1: Laps 1–8 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 2: Laps 9–11 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 3: Laps 12–18 | Compound: SOFT
#   Silverstone - Practice 1: Stint 4: Laps 19–28 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 1: Laps 1–6 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 2: Laps 7–9 | Compound: SOFT
#   Silverstone - Practice 2: Stint 3: Laps 10–24 | Compound: SOFT
#   Silverstone - Practice 2: Stint 4: Laps 25–27 | Compound: MEDIUM
#   Silverstone - Practice 3: Stint 1: Laps 1–8 | Compound: HARD
#   Silverstone - Practice 3: Stint 2: Laps 9–9 | Compound: HARD
#   Silverstone - Practice 3: Stint 3: Laps 10–12 | Compound: SOFT
#   Silverstone - Practice 3: Stint 4: Laps 13–14 | Compound: SOFT
#   Silverstone - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Silverstone - Race: Stint 1: Laps 1–10 | Compound: MEDIUM
#   Silverstone - Race: Stint 2: Laps 11–17 | Compound: INTERMEDIATE
#
# 📈 Session Positions:
#   Spa-Francorchamps - Practice 1: Grid → 4, Finish → 10
#   Spa-Francorchamps - Sprint Qualifying: Grid → 10, Finish → 9
#   Spa-Francorchamps - Sprint: Grid → 9, Finish → 8
#   Spa-Francorchamps - Qualifying: Grid → 10, Finish → 8
#   Spa-Francorchamps - Race: Grid → 8, Finish → 20
#   Hungaroring - Practice 1: Grid → 4, Finish → 10
#   Hungaroring - Practice 2: Grid → 4, Finish → 8
#   Hungaroring - Practice 3: Grid → 5, Finish → 20
#   Hungaroring - Qualifying: Grid → 20, Finish → 10
#   Hungaroring - Race: Grid → 11, Finish → 11
#   Silverstone - Practice 1: Grid → 4, Finish → 6
#   Silverstone - Practice 2: Grid → 4, Finish → 9
#   Silverstone - Practice 3: Grid → 4, Finish → 9
#   Silverstone - Qualifying: Grid → 9, Finish → 13
#   Silverstone - Race: Grid → 12, Finish → 17
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#  Hungaroring - Race [BLUE @ 2025-08-03 14:31:21+00:00] Reason: WAVED BLUE FLAG FOR CAR 6 (HAD) TIMED AT 16:31:21
#  Hungaroring - Race [BLUE @ 2025-08-03 14:31:59+00:00] Reason: WAVED BLUE FLAG FOR CAR 6 (HAD) TIMED AT 16:31:58
#  Spa-Francorchamps - Race [BLUE @ 2025-07-27 15:35:18+00:00] Reason: WAVED BLUE FLAG FOR CAR 6 (HAD) TIMED AT 17:35:18
#  Spa-Francorchamps - Race [BLUE @ 2025-07-27 15:37:40+00:00] Reason: WAVED BLUE FLAG FOR CAR 6 (HAD) TIMED AT 17:37:40
#  Spa-Francorchamps - Race [BLUE @ 2025-07-27 15:37:44+00:00] Reason: WAVED BLUE FLAG FOR CAR 6 (HAD) TIMED AT 17:37:44
#  Spa-Francorchamps - Race [BLUE @ 2025-07-27 15:37:53+00:00] Reason: WAVED BLUE FLAG FOR CAR 6 (HAD) TIMED AT 17:37:52
#
# ------------------------------------------------------------
#
# 🏎️  Driver: Pierre GASLY (P GASLY)
# 🏁 Team: Alpine | Country: FRA
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 10: 14
#   Hungaroring - Practice 1: Best Lap = 77.123s | Avg = 100.943s | Consistency = 22.823s
#   Hungaroring - Practice 2: Best Lap = 77.043s | Avg = 93.888s | Consistency = 18.502s
#   Hungaroring - Practice 3: Best Lap = 76.570s | Avg = 92.637s | Consistency = 19.406s
#   Hungaroring - Qualifying: Best Lap = 75.966s | Avg = 95.853s | Consistency = 23.921s
#   Hungaroring - Race: Best Lap = 81.433s | Avg = 83.138s | Consistency = 0.963s
#   Spa-Francorchamps - Practice 1: Best Lap = 103.929s | Avg = 131.402s | Consistency = 25.064s
#   Spa-Francorchamps - Sprint Qualifying: Best Lap = 101.949s | Avg = 122.664s | Consistency = 25.301s
#   Spa-Francorchamps - Qualifying: Best Lap = 101.633s | Avg = 119.438s | Consistency = 18.761s
#   Spa-Francorchamps - Race: Best Lap = 107.177s | Avg = 115.604s | Consistency = 17.036s
#   Silverstone - Practice 1: Best Lap = 88.332s | Avg = 116.613s | Consistency = 26.104s
#   Silverstone - Practice 2: Best Lap = 87.174s | Avg = 110.083s | Consistency = 24.003s
#   Silverstone - Practice 3: Best Lap = 87.878s | Avg = 108.910s | Consistency = 25.825s
#   Silverstone - Qualifying: Best Lap = 85.711s | Avg = 100.165s | Consistency = 15.267s
#   Silverstone - Race: Best Lap = 90.751s | Avg = 112.916s | Consistency = 21.745s
#
# ⛽ Pit Stops:
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 5 | Duration: 219.2s
#   Hungaroring - Practice 1: 🔁 Lap 11 | Duration: 25.4s
#   Hungaroring - Practice 1: 🔁 Lap 14 | Duration: 478.2s
#   Hungaroring - Practice 1: 🔁 Lap 20 | Duration: 321.3s
#   Hungaroring - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 1: 🔁 Lap 5 | Duration: 219.2s
#   Hungaroring - Practice 2: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 2: 🔁 Lap 7 | Duration: 993.8s
#   Hungaroring - Practice 2: 🔁 Lap 9 | Duration: 25.0s
#   Hungaroring - Practice 2: 🔁 Lap 12 | Duration: 16.4s
#   Hungaroring - Practice 2: 🔁 Lap 15 | Duration: 360.3s
#   Hungaroring - Practice 3: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 3: 🔁 Lap 4 | Duration: 16.4s
#   Hungaroring - Practice 3: 🔁 Lap 7 | Duration: 582.9s
#   Hungaroring - Practice 3: 🔁 Lap 15 | Duration: 469.6s
#   Hungaroring - Practice 3: 🔁 Lap 19 | Duration: 24.6s
#   Hungaroring - Qualifying: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Qualifying: 🔁 Lap 4 | Duration: 210.4s
#   Hungaroring - Race: 🔁 Lap 32 | Duration: 21.6s
#   Spa-Francorchamps - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Spa-Francorchamps - Practice 1: 🔁 Lap 9 | Duration: 520.2s
#   Spa-Francorchamps - Practice 1: 🔁 Lap 13 | Duration: 553.3s
#   Spa-Francorchamps - Practice 1: 🔁 Lap 15 | Duration: 38.2s
#   Spa-Francorchamps - Sprint Qualifying: 🔁 Lap 1 | Duration: ?s
#   Spa-Francorchamps - Sprint Qualifying: 🔁 Lap 4 | Duration: 32.1s
#   Spa-Francorchamps - Sprint Qualifying: 🔁 Lap 7 | Duration: 991.5s
#   Spa-Francorchamps - Sprint Qualifying: 🔁 Lap 10 | Duration: 880.5s
#   Spa-Francorchamps - Qualifying: 🔁 Lap 1 | Duration: ?s
#   Spa-Francorchamps - Qualifying: 🔁 Lap 3 | Duration: 111.6s
#   Spa-Francorchamps - Qualifying: 🔁 Lap 6 | Duration: 144.5s
#   Spa-Francorchamps - Qualifying: 🔁 Lap 9 | Duration: 375.1s
#   Spa-Francorchamps - Qualifying: 🔁 Lap 12 | Duration: 121.8s
#   Spa-Francorchamps - Race: 🔁 Lap 11 | Duration: 26.8s
#   Silverstone - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Silverstone - Practice 1: 🔁 Lap 8 | Duration: 695.4s
#   Silverstone - Practice 1: 🔁 Lap 12 | Duration: 34.5s
#   Silverstone - Practice 1: 🔁 Lap 17 | Duration: 152.5s
#   Silverstone - Practice 1: 🔁 Lap 18 | Duration: 392.2s
#   Silverstone - Practice 2: 🔁 Lap 1 | Duration: ?s
#   Silverstone - Practice 2: 🔁 Lap 7 | Duration: 52.9s
#   Silverstone - Practice 2: 🔁 Lap 10 | Duration: 781.5s
#   Silverstone - Practice 2: 🔁 Lap 13 | Duration: 42.9s
#   Silverstone - Practice 2: 🔁 Lap 16 | Duration: 34.1s
#   Silverstone - Practice 2: 🔁 Lap 18 | Duration: 312.9s
#   Silverstone - Practice 3: 🔁 Lap 1 | Duration: ?s
#   Silverstone - Practice 3: 🔁 Lap 7 | Duration: 1188.0s
#   Silverstone - Practice 3: 🔁 Lap 14 | Duration: 426.3s
#   Silverstone - Practice 3: 🔁 Lap 15 | Duration: 775.2s
#   Silverstone - Qualifying: 🔁 Lap 1 | Duration: ?s
#   Silverstone - Qualifying: 🔁 Lap 7 | Duration: ?s
#   Silverstone - Qualifying: 🔁 Lap 10 | Duration: 458.9s
#   Silverstone - Qualifying: 🔁 Lap 13 | Duration: 242.0s
#   Silverstone - Qualifying: 🔁 Lap 16 | Duration: 427.1s
#   Silverstone - Qualifying: 🔁 Lap 19 | Duration: 151.0s
#   Silverstone - Race: 🔁 Lap 11 | Duration: 28.9s
#   Silverstone - Race: 🔁 Lap 41 | Duration: 28.4s
#
# 🛞 Tire Stints:
#   Hungaroring - Practice 1: Stint 3: Laps 11–13 | Compound: MEDIUM
#   Hungaroring - Practice 1: Stint 4: Laps 14–19 | Compound: SOFT
#   Hungaroring - Practice 1: Stint 5: Laps 20–27 | Compound: MEDIUM
#   Hungaroring - Practice 1: Stint 1: Laps 1–4 | Compound: MEDIUM
#   Hungaroring - Practice 1: Stint 2: Laps 5–5 | Compound: MEDIUM
#   Hungaroring - Practice 2: Stint 1: Laps 1–6 | Compound: MEDIUM
#   Hungaroring - Practice 2: Stint 2: Laps 7–8 | Compound: MEDIUM
#   Hungaroring - Practice 2: Stint 3: Laps 9–11 | Compound: SOFT
#   Hungaroring - Practice 2: Stint 4: Laps 12–14 | Compound: SOFT
#   Hungaroring - Practice 2: Stint 5: Laps 15–25 | Compound: MEDIUM
#   Hungaroring - Practice 3: Stint 1: Laps 1–3 | Compound: SOFT
#   Hungaroring - Practice 3: Stint 2: Laps 4–6 | Compound: SOFT
#   Hungaroring - Practice 3: Stint 3: Laps 7–14 | Compound: SOFT
#   Hungaroring - Practice 3: Stint 4: Laps 15–18 | Compound: SOFT
#   Hungaroring - Practice 3: Stint 5: Laps 19–22 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Hungaroring - Race: Stint 1: Laps 1–32 | Compound: HARD
#   Hungaroring - Race: Stint 2: Laps 33–69 | Compound: MEDIUM
#   Spa-Francorchamps - Practice 1: Stint 1: Laps 1–8 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 2: Laps 9–12 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 3: Laps 13–14 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 4: Laps 15–21 | Compound: SOFT
#   Spa-Francorchamps - Sprint Qualifying: Stint 1: Laps 1–3 | Compound: MEDIUM
# ...
#
# 🛞 Tire Stints:
#   Hungaroring - Practice 2: Stint 1: Laps 1–7 | Compound: MEDIUM
#   Hungaroring - Practice 2: Stint 2: Laps 8–11 | Compound: MEDIUM
#   Hungaroring - Practice 2: Stint 3: Laps 12–14 | Compound: SOFT
#   Hungaroring - Practice 2: Stint 4: Laps 15–17 | Compound: SOFT
#   Hungaroring - Practice 2: Stint 5: Laps 18–25 | Compound: SOFT
#   Hungaroring - Practice 3: Stint 1: Laps 1–1 | Compound: MEDIUM
#   Hungaroring - Practice 3: Stint 2: Laps 2–2 | Compound: HARD
#   Hungaroring - Practice 3: Stint 3: Laps 3–7 | Compound: MEDIUM
#   Hungaroring - Practice 3: Stint 4: Laps 8–11 | Compound: MEDIUM
#   Hungaroring - Practice 3: Stint 5: Laps 12–14 | Compound: SOFT
#   Hungaroring - Practice 3: Stint 6: Laps 15–18 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Hungaroring - Qualifying: Stint 5: Laps 13–15 | Compound: SOFT
#   Hungaroring - Race: Stint 1: Laps 1–39 | Compound: MEDIUM
#   Hungaroring - Race: Stint 2: Laps 40–70 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 1: Laps 1–7 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 2: Laps 8–16 | Compound: HARD
#   Spa-Francorchamps - Practice 1: Stint 3: Laps 17–19 | Compound: SOFT
#   Spa-Francorchamps - Practice 1: Stint 4: Laps 20–22 | Compound: HARD
#   Spa-Francorchamps - Sprint Qualifying: Stint 1: Laps 1–4 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint Qualifying: Stint 2: Laps 5–7 | Compound: MEDIUM
#   Spa-Francorchamps - Sprint: Stint 1: Laps 1–15 | Compound: MEDIUM
#   Spa-Francorchamps - Qualifying: Stint 1: Laps 1–2 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 2: Laps 3–5 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 3: Laps 6–8 | Compound: SOFT
#   Spa-Francorchamps - Race: Stint 1: Laps 1–1 | Compound: INTERMEDIATE
#   Spa-Francorchamps - Race: Stint 2: Laps 2–11 | Compound: MEDIUM
#   Spa-Francorchamps - Race: Stint 3: Laps 12–44 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 1: Laps 1–9 | Compound: HARD
#   Silverstone - Practice 1: Stint 2: Laps 10–12 | Compound: SOFT
#   Silverstone - Practice 1: Stint 3: Laps 13–17 | Compound: SOFT
#   Silverstone - Practice 1: Stint 4: Laps 18–24 | Compound: HARD
#   Silverstone - Practice 2: Stint 1: Laps 1–8 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 2: Laps 9–11 | Compound: SOFT
#   Silverstone - Practice 2: Stint 3: Laps 12–14 | Compound: SOFT
#   Silverstone - Practice 2: Stint 4: Laps 15–24 | Compound: MEDIUM
#   Silverstone - Practice 3: Stint 1: Laps 1–1 | Compound: MEDIUM
#   Silverstone - Practice 3: Stint 2: Laps 2–2 | Compound: HARD
#   Silverstone - Practice 3: Stint 3: Laps 3–8 | Compound: MEDIUM
#   Silverstone - Practice 3: Stint 4: Laps 9–13 | Compound: MEDIUM
#   Silverstone - Practice 3: Stint 5: Laps 14–14 | Compound: SOFT
#   Silverstone - Practice 3: Stint 6: Laps 15–16 | Compound: SOFT
#   Silverstone - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Qualifying: Stint 4: Laps 10–12 | Compound: SOFT
#   Silverstone - Qualifying: Stint 5: Laps 13–15 | Compound: SOFT
#   Silverstone - Race: Stint 1: Laps 1–11 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 2: Laps 12–37 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 3: Laps 38–52 | Compound: MEDIUM
#
# 📈 Session Positions:
#   Spa-Francorchamps - Practice 1: Grid → 7, Finish → 9
#   Spa-Francorchamps - Sprint Qualifying: Grid → 9, Finish → 14
#   Spa-Francorchamps - Sprint: Grid → 14, Finish → 14
#   Spa-Francorchamps - Qualifying: Grid → 9, Finish → 19
#   Spa-Francorchamps - Race: Grid → 20, Finish → 17
#   Hungaroring - Practice 2: Grid → 7, Finish → 5
#   Hungaroring - Practice 3: Grid → 8, Finish → 6
#   Hungaroring - Qualifying: Grid → 6, Finish → 5
#   Hungaroring - Race: Grid → 4, Finish → 5
#   Silverstone - Practice 1: Grid → 7, Finish → 11
#   Silverstone - Practice 2: Grid → 7, Finish → 12
#   Silverstone - Practice 3: Grid → 7, Finish → 17
#   Silverstone - Qualifying: Grid → 17, Finish → 9
#   Silverstone - Race: Grid → 7, Finish → 9
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#   No incidents recorded.
#
# ------------------------------------------------------------
#
# 🏎️  Driver: Nico HULKENBERG (N HULKENBERG)
# 🏁 Team: Kick Sauber | Country: Unknown
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 27: 12
#   Hungaroring - Practice 2: Best Lap = 76.680s | Avg = 93.710s | Consistency = 21.113s
#   Hungaroring - Practice 3: Best Lap = 76.025s | Avg = 90.756s | Consistency = 17.011s
#   Hungaroring - Qualifying: Best Lap = 76.081s | Avg = 87.058s | Consistency = 12.724s
#   Hungaroring - Race: Best Lap = 80.013s | Avg = 82.536s | Consistency = 1.372s
#   Spa-Francorchamps - Practice 1: Best Lap = 103.470s | Avg = 131.051s | Consistency = 32.541s
#   Spa-Francorchamps - Sprint Qualifying: Best Lap = 103.217s | Avg = 122.886s | Consistency = 22.554s
#   Spa-Francorchamps - Qualifying: Best Lap = 101.707s | Avg = 114.656s | Consistency = 16.246s
#   Spa-Francorchamps - Race: Best Lap = 105.068s | Avg = 115.483s | Consistency = 17.266s
#   Silverstone - Practice 2: Best Lap = 87.165s | Avg = 106.981s | Consistency = 22.118s
#   Silverstone - Practice 3: Best Lap = 86.499s | Avg = 99.937s | Consistency = 18.579s
#   Silverstone - Qualifying: Best Lap = 86.574s | Avg = 98.503s | Consistency = 15.721s
#   Silverstone - Race: Best Lap = 90.933s | Avg = 112.472s | Consistency = 22.074s
#
# ⛽ Pit Stops:
#   Hungaroring - Practice 2: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 2: 🔁 Lap 6 | Duration: 16.5s
#   Hungaroring - Practice 2: 🔁 Lap 9 | Duration: 16.5s
#   Hungaroring - Practice 2: 🔁 Lap 12 | Duration: 427.6s
#   Hungaroring - Practice 2: 🔁 Lap 15 | Duration: 30.0s
#   Hungaroring - Practice 2: 🔁 Lap 18 | Duration: 396.0s
#   Hungaroring - Practice 2: 🔁 Lap 29 | Duration: 21.6s
#   Hungaroring - Practice 3: 🔁 Lap 1 | Duration: ?s
#   Hungaroring - Practice 3: 🔁 Lap 4 | Duration: 145.2s
#   Hungaroring - Practice 3: 🔁 Lap 13 | Duration: 778.8s
#   Hungaroring - Practice 3: 🔁 Lap 16 | Duration: 160.2s
#   Hungaroring - Practice 3: 🔁 Lap 19 | Duration: 180.4s
#   Hungaroring - Qualifying: 🔁 Lap 1 | Duration: ?s
#   
| Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 2: Laps 3–5 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 3: Laps 6–8 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 4: Laps 9–11 | Compound: SOFT
#   Spa-Francorchamps - Qualifying: Stint 5: Laps 12–14 | Compound: SOFT
#   Spa-Francorchamps - Race: Stint 1: Laps 1–1 | Compound: INTERMEDIATE
#   Spa-Francorchamps - Race: Stint 2: Laps 2–11 | Compound: MEDIUM
#   Spa-Francorchamps - Race: Stint 3: Laps 12–44 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 1: Laps 1–9 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 2: Laps 10–15 | Compound: SOFT
#   Silverstone - Practice 2: Stint 3: Laps 16–26 | Compound: MEDIUM
#   Silverstone - Practice 2: Stint 4: Laps 27–29 | Compound: SOFT
#   Silverstone - Practice 3: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Practice 3: Stint 2: Laps 4–13 | Compound: SOFT
#   Silverstone - Practice 3: Stint 3: Laps 14–16 | Compound: SOFT
#   Silverstone - Practice 3: Stint 4: Laps 17–17 | Compound: SOFT
#   Silverstone - Practice 3: Stint 5: Laps 18–19 | Compound: SOFT
#   Silverstone - Qualifying: Stint 1: Laps 1–3 | Compound: SOFT
#   Silverstone - Qualifying: Stint 2: Laps 4–6 | Compound: SOFT
#   Silverstone - Qualifying: Stint 3: Laps 7–9 | Compound: SOFT
#   Silverstone - Race: Stint 1: Laps 1–9 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 2: Laps 10–42 | Compound: INTERMEDIATE
#   Silverstone - Race: Stint 3: Laps 43–52 | Compound: MEDIUM
#
# 📈 Session Positions:
#   Spa-Francorchamps - Practice 1: Grid → 12, Finish → 14
#   Spa-Francorchamps - Sprint Qualifying: Grid → 14, Finish → 17
#   Spa-Francorchamps - Sprint: Grid → 17, Finish → 18
#   Spa-Francorchamps - Qualifying: Grid → 14, Finish → 14
#   Spa-Francorchamps - Race: Grid → 14, Finish → 12
#   Hungaroring - Practice 2: Grid → 12, Finish → 12
#   Hungaroring - Practice 3: Grid → 13, Finish → 10
#   Hungaroring - Qualifying: Grid → 10, Finish → 19
#   Hungaroring - Race: Grid → 19, Finish → 13
#   Silverstone - Practice 2: Grid → 12, Finish → 17
#   Silverstone - Practice 3: Grid → 12, Finish → 15
#   Silverstone - Qualifying: Grid → 15, Finish → 19
#   Silverstone - Race: Grid → 19, Finish → 3
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#  Hungaroring - Race [BLUE @ 2025-08-03 14:01:01+00:00] Reason: WAVED BLUE FLAG FOR CAR 27 (HUL) TIMED AT 16:01:01
#  Hungaroring - Race [BLUE @ 2025-08-03 14:12:43+00:00] Reason: WAVED BLUE FLAG FOR CAR 27 (HUL) TIMED AT 16:12:43
#  Hungaroring - Race [BLUE @ 2025-08-03 14:20:54+00:00] Reason: WAVED BLUE FLAG FOR CAR 27 (HUL) TIMED AT 16:20:53
#  Hungaroring - Race [BLUE @ 2025-08-03 14:21:11+00:00] Reason: WAVED BLUE FLAG FOR CAR 27 (HUL) TIMED AT 16:21:11
#  Hungaroring - Race [BLUE @ 2025-08-03 14:35:10+00:00] Reason: WAVED BLUE FLAG FOR CAR 27 (HUL) TIMED AT 16:35:09
#  Hungaroring - Race [BLUE @ 2025-08-03 14:35:42+00:00] Reason: WAVED BLUE FLAG FOR CAR 27 (HUL) TIMED AT 16:35:42
#
# ------------------------------------------------------------
#
# 🏎️  Driver: Arvid LINDBLAD (A LINDBLAD)
# 🏁 Team: Red Bull Racing | Country: Unknown
#
# 📊 Lap Performance:
# 🔍 Lap entries found for driver 36: 1
#   Silverstone - Practice 1: Best Lap = 87.958s | Avg = 119.098s | Consistency = 27.122s
#
# ⛽ Pit Stops:
#   Silverstone - Practice 1: 🔁 Lap 1 | Duration: ?s
#   Silverstone - Practice 1: 🔁 Lap 9 | Duration: 360.3s
#   Silverstone - Practice 1: 🔁 Lap 12 | Duration: 33.7s
#   Silverstone - Practice 1: 🔁 Lap 15 | Duration: 446.0s
#   Silverstone - Practice 1: 🔁 Lap 18 | Duration: 34.3s
#
# 🛞 Tire Stints:
#   Silverstone - Practice 1: Stint 1: Laps 1–8 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 2: Laps 9–11 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 3: Laps 12–14 | Compound: MEDIUM
#   Silverstone - Practice 1: Stint 4: Laps 15–17 | Compound: SOFT
#   Silverstone - Practice 1: Stint 5: Laps 18–22 | Compound: SOFT
#
# 📈 Session Positions:
#   Silverstone - Practice 1: Grid → 13, Finish → 14
#
# 🌦️ Weather Summary:
#   Spa-Francorchamps - Practice 1: Wet (Max Rainfall: 1.00)
#   Spa-Francorchamps - Sprint Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Sprint: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Qualifying: Dry (Max Rainfall: 0.00)
#   Spa-Francorchamps - Race: Wet (Max Rainfall: 1.00)
#   Hungaroring - Practice 1: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 2: Dry (Max Rainfall: 0.00)
#   Hungaroring - Practice 3: Dry (Max Rainfall: 0.00)
#   Hungaroring - Qualifying: Dry (Max Rainfall: 0.00)
#   Hungaroring - Race: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 1: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 2: Dry (Max Rainfall: 0.00)
#   Silverstone - Practice 3: Dry (Max Rainfall: 0.00)
#   Silverstone - Qualifying: Dry (Max Rainfall: 0.00)
#   Silverstone - Race: Wet (Max Rainfall: 1.00)
#
# 🚩 Race Control Events:
#   No incidents recorded.
#
# ------------------------------------------------------------
